# %%
import pandas as pd

# %%
url_1 = pd.read_csv('Data sets/URL dataset.csv')

# %%
pusing = pd.read_csv('Data sets/Phishing URLs.csv')

# %%
malicious = pd.read_csv('Data sets/malicious_phish.csv')

# %%
upi = pd.read_csv('Data sets/upi_transactions_2024.csv')

# %% [markdown]
# ## 1. URL Datasets

# %%
url_1.sample(10)
# Out:
#                                                       url        type
# 394185                       http://stafflog.co.za/aa.php    phishing
# 273460          https://www.planetmagrathea.com/22/81498/  legitimate
# 105496  https://www.thejustinianforum.org/memberdirect...  legitimate
# 54077   https://www.guetalisadc.blogspot.com/2008_10_0...  legitimate
# 181421  https://www.eonline.com/celebs/Tom_Selleck/116891  legitimate
# 49570   https://www.freepages.genealogy.rootsweb.ances...  legitimate
# 385223     http://wbyd.org/wp-includes/js/jquery/ui/usaa1    phishing
# 242533  https://www.manta.com/c/mtmfx9m/assembly-membe...  legitimate
# 139926  https://www.answers.com/topic/the-kid-stays-in...  legitimate
# 181550  https://www.epinions.com/review/The_Coquette_b...  legitimate

# %%
url_1['type'].unique()
# Out:
# array(['legitimate', 'phishing'], dtype=object)

# %%
url_1['type'].value_counts()
# Out:
# type
# legitimate    345738
# phishing      104438
# Name: count, dtype: int64

# %%
url_1.isnull().mean()*100
# Out:
# url     0.0
# type    0.0
# dtype: float64

# %%
url_1.duplicated().sample(10)
# Out:
# 428156    False
# 356351    False
# 160984    False
# 202634    False
# 104481    False
# 411858    False
# 28844     False
# 95502     False
# 42657     False
# 101614    False
# dtype: bool

# %%
url_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450176 entries, 0 to 450175
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   url     450176 non-null  object
#  1   type    450176 non-null  object
# dtypes: object(2)
# memory usage: 6.9+ MB

# %%
new_url_1 = url_1[['url', 'type']].rename(columns={'url': 'URL', 'type': 'label'})

# %%
new_url_1.sample(10)
# Out:
#                                                       URL       label
# 341272        https://www.aec.sram.qc.ca/informations/en/  legitimate
# 161856                https://www.charlestaylortrial.org/  legitimate
# 10312   https://www.bloguay.com/bomiti/2011/11/14/one-...  legitimate
# 114554  https://www.vivalesbootlegs.blogspot.com/2009/...  legitimate
# 420690      http://duniaserviceac.com/wp-content/upgrade/    phishing
# 58452   https://www.iepolitics.com/category/state-asse...  legitimate
# 158377  https://www.cartoonbrew.com/animators/ryan-lar...  legitimate
# 59783   https://www.investor.wedbush.com/wedbush/news/...  legitimate
# 322337  https://www.whosampled.com/sample/view/20431/E...  legitimate
# 351735  http://hiroba.dqx.jp.iuxzl.usa.cc/account/app/...    phishing

# %% [markdown]
# ## 2. Pusing URL Datasets

# %%
pusing.sample(10)
# Out:
#                                                      url      Type
# 17413  https://ipfs.io/ipfs/Qme8L9eNj1BD2XhvAkmDzw2zS...  Phishing
# 39793  https://bafkreihkh3oopomnzwblrmvowq5xk7rhhywr4...  Phishing
# 4270                https://greens-bitcoins.web.app/app/  Phishing
# 10438    https://tripsloerdkekviz.zavier4766.workers.dev  Phishing
# 5391                      https://usps.mytrackingyg.top/  Phishing
# 19131  https://docs.google.com/presentation/d/e/2PACX...  Phishing
# 16526                            https://t.co/7Cz7HKEGGT  Phishing
# 48575  https://bafybeibaa7e3gul6xq5pbnlr3h7iqpxinnrr2...  Phishing
# 43789  https://ipfs.eth.aragon.network/ipfs/bafybeifq...  Phishing
# 46367  https://docs.google.com/presentation/d/e/2PACX...  Phishing

# %%
pusing['Type'].unique()
# Out:
# array(['Phishing'], dtype=object)

# %%
pusing.isnull().mean()*100
# Out:
# url     0.0
# Type    0.0
# dtype: float64

# %%
pusing['Type'].value_counts()
# Out:
# Type
# Phishing    54807
# Name: count, dtype: int64

# %%
pusing.duplicated().sample(10)
# Out:
# 10298    False
# 11527    False
# 15070    False
# 29551    False
# 28155    False
# 33830    False
# 4157     False
# 49221    False
# 20186    False
# 34072    False
# dtype: bool

# %%
pusing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54807 entries, 0 to 54806
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   url     54807 non-null  object
#  1   Type    54807 non-null  object
# dtypes: object(2)
# memory usage: 856.5+ KB

# %%
new_pusing = pusing[['url', 'Type']].rename(columns={'url': 'URL', 'Type': 'label'})

# %%
new_pusing.head()
# Out:
#                                                  URL     label
# 0  https://docs.google.com/presentation/d/e/2PACX...  Phishing
# 1    https://btttelecommunniccatiion.weeblysite.com/  Phishing
# 2                        https://kq0hgp.webwave.dev/  Phishing
# 3  https://brittishtele1bt-69836.getresponsesite....  Phishing
# 4         https://bt-internet-105056.weeblysite.com/  Phishing

# %%
new_pusing['label'].value_counts()
# Out:
# label
# Phishing    54807
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Malicious pish Datasets

# %%
malicious.head()
# Out:
#                                                  url        type
# 0                                   br-icloud.com.br    phishing
# 1                mp3raid.com/music/krizz_kaliko.html      benign
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement

# %%
malicious['type'].value_counts()
# Out:
# type
# benign        428103
# defacement     96457
# phishing       94111
# malware        32520
# Name: count, dtype: int64

# %%
malicious.isnull().sum()
# Out:
# url     0
# type    0
# dtype: int64

# %%
malicious.duplicated().sample(10)
# Out:
# 333887    False
# 395966    False
# 531500    False
# 118884    False
# 647141    False
# 130632    False
# 138897    False
# 208120    False
# 423409    False
# 280035    False
# dtype: bool

# %%
malicious.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651191 entries, 0 to 651190
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   url     651191 non-null  object
#  1   type    651191 non-null  object
# dtypes: object(2)
# memory usage: 9.9+ MB

# %%
new_malicious = malicious[['url', 'type']].rename(columns={'url': 'URL', 'type': 'label'})

# %%
new_malicious.head()
# Out:
#                                                  URL       label
# 0                                   br-icloud.com.br    phishing
# 1                mp3raid.com/music/krizz_kaliko.html      benign
# 2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4  http://adventure-nicaragua.net/index.php?optio...  defacement

# %% [markdown]
# ## 4. UPI transaction Datasets

# %%
upi.sample(10)
# Out:
#        transaction id            timestamp transaction type merchant_category  \
# 194032  TXN0000194033  2024-08-08 11:59:13              P2P         Utilities
# 59120   TXN0000059121  2024-06-29 16:55:15              P2M             Other
# 192734  TXN0000192735  2024-10-09 16:23:07              P2P           Grocery
# 51015   TXN0000051016  2024-05-17 18:10:43         Recharge         Education
# 89848   TXN0000089849  2024-05-22 10:49:53              P2P         Transport
# 44849   TXN0000044850  2024-11-17 19:17:28              P2P              Food
# 72161   TXN0000072162  2024-02-07 08:02:49              P2M          Shopping
# 82710   TXN0000082711  2024-07-30 10:56:29              P2M           Grocery
# 220970  TXN0000220971  2024-11-17 00:42:11              P2M          Shopping
# 82489   TXN0000082490  2024-05-25 16:35:59              P2P              Fuel
#
#         amount (INR) transaction_status sender_age_group receiver_age_group  \
# 194032          5614            SUCCESS            36-45              26-35
# 59120            448            SUCCESS              56+              26-35
# 192734           560            SUCCESS            26-35              18-25
# 51015            913            SUCCESS            36-45              36-45
# 89848            411            SUCCESS            36-45              36-45
# 44849            630            SUCCESS            26-35              18-25
# 72161            805            SUCCESS            26-35              46-55
# 82710            535            SUCCESS            18-25              46-55
# 220970          3507            SUCCESS            26-35              36-45
# 82489           2692            SUCCESS            36-45              46-55
#
#           sender_state sender_bank receiver_bank device_type network_type  \
# 194032       Karnataka        HDFC           PNB         iOS           4G
# 59120   Andhra Pradesh         SBI          HDFC         Web           5G
# 192734       Telangana       ICICI           SBI     Android           4G
# 51015            Delhi        HDFC           SBI     Android         WiFi
# 89848       Tamil Nadu         SBI           SBI     Android           4G
# 44849      West Bengal    Yes Bank      Yes Bank     Android           4G
# 72161      Maharashtra       ICICI           PNB     Android           5G
# 82710    Uttar Pradesh    Yes Bank           SBI     Android           4G
# 220970      Tamil Nadu        Axis           SBI     Android           4G
# 82489            Delhi    IndusInd          HDFC     Android           5G
#
#         fraud_flag  hour_of_day day_of_week  is_weekend
# 194032           0           11    Thursday           0
# 59120            0           16    Saturday           1
# 192734           0           16   Wednesday           0
# 51015            0           18      Friday           0
# 89848            0           10   Wednesday           0
# 44849            0           19      Sunday           1
# 72161            0            8   Wednesday           0
# 82710            0           10     Tuesday           0
# 220970           0            0      Sunday           1
# 82489            0           16    Saturday           1

# %%
upi.isnull().mean()*100
# Out:
# transaction id        0.0
# timestamp             0.0
# transaction type      0.0
# merchant_category     0.0
# amount (INR)          0.0
# transaction_status    0.0
# sender_age_group      0.0
# receiver_age_group    0.0
# sender_state          0.0
# sender_bank           0.0
# receiver_bank         0.0
# device_type           0.0
# network_type          0.0
# fraud_flag            0.0
# hour_of_day           0.0
# day_of_week           0.0
# is_weekend            0.0
# dtype: float64

# %%
upi.duplicated().sample(10)
# Out:
# 107505    False
# 204475    False
# 9095      False
# 143863    False
# 91050     False
# 218356    False
# 145082    False
# 226101    False
# 157294    False
# 243994    False
# dtype: bool

# %%
upi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   timestamp           250000 non-null  object
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
#  10  receiver_bank       250000 non-null  object
#  11  device_type         250000 non-null  object
#  12  network_type        250000 non-null  object
#  13  fraud_flag          250000 non-null  int64
#  14  hour_of_day         250000 non-null  int64
#  15  day_of_week         250000 non-null  object
#  16  is_weekend          250000 non-null  int64
# dtypes: int64(4), object(13)
# memory usage: 32.4+ MB

# %%
upi.nunique()
# Out:
# transaction id        250000
# timestamp             248610
# transaction type           4
# merchant_category         10
# amount (INR)           10355
# transaction_status         2
# sender_age_group           5
# receiver_age_group         5
# sender_state              10
# sender_bank                8
# receiver_bank              8
# device_type                3
# network_type               4
# fraud_flag                 2
# hour_of_day               24
# day_of_week                7
# is_weekend                 2
# dtype: int64

# %% [markdown]
#      https://www.kaggle.com/datasets/skullagos5246/upi-transactions-2024-dataset
# ## Description:
#
#      This is the main dataset file containing all simulated UPI transaction records, including transaction metadata, user demographics, payment             details, and derived temporal features.
#
# ## Columns:
#
#      transaction id: Unique identifier for each transaction (e.g., TXN0000000001)
#
#      timestamp: Date and time of transaction (YYYY-MM-DD HH:MM:SS)
#
#      transaction type: Type of transaction (P2P, P2M, Bill Payment, Recharge)
#
#      merchant_category: Category of the merchant (Food, Grocery, Fuel, Entertainment, Shopping, Healthcare, Education, Transport, Utilities, Other)
#
#      amount (INR): Transaction value in Indian Rupees
#
#      transaction_status: Status of transaction (SUCCESS, FAILED)
#
#      sender_age_group: Age group of the sender (18-25, 26-35, 36-45, 46-55, 56+)
#
#      receiver_age_group: Age group of the receiver (18-25, 26-35, 36-45, 46-55, 56+)
#
#      sender_state: State of the sender (Maharashtra, Karnataka, Delhi, Tamil Nadu, West Bengal, Gujarat, Rajasthan, Uttar Pradesh, Andhra Pradesh,          Telangana)
#
#      sender_bank: Bank of the sender (SBI, HDFC, ICICI, Axis, PNB, Kotak, IndusInd, Yes Bank)
#
#      receiver_bank: Bank of the receiver (SBI, HDFC, ICICI, Axis, PNB, Kotak, IndusInd, Yes Bank)
#
#      device_type: Type of device used (Android, iOS, Web)
#
#      network_type: Network connection type (4G, 5G, WiFi, 3G)
#
#      fraud_flag: Fraud indicator (0 = genuine, 1 = fraudulent)
#
#      hour_of_day: Hour of the day (0-23)
#
#      day_of_week: Day of the week (Monday, Tuesday, …, Sunday)
#
#      is_weekend: Binary flag for weekend (0 = weekday, 1 = weekend)

# %% [markdown]
# ## 5. Combine all URLs Datasets

# %%
merge_data = pd.concat([new_url_1, new_pusing, new_malicious], ignore_index=True)
print(f"Total URLs after combining: {len(merge_data)}")
# Out:
# Total URLs after combining: 1156174

# %%
merge_data.sample(10)
# Out:
#                                                        URL       label
# 594722         unwiredsignal.com/?c=145&cn=Mobile+Antennas      benign
# 336020         https://www.youtube.com/watch?v=nZHfJKDJh-s  legitimate
# 900159   http://www.oficynafoka.com/index2.php?option=c...  defacement
# 1021689  http://xsc.wfu.edu.cn/picture/article/16/9c/2a...     malware
# 779699   cardboardinvestor.com/index.php?cPath=28_1485_...      benign
# 71889    https://www.michigansportscenter.com/2009/08/d...  legitimate
# 1009723            halloweenmovie.wikia.com/wiki/Kim_Darby      benign
# 459917                 http://lansingisyoung-28l.pages.dev    Phishing
# 912182    allrovi.com/name/wayne-morris-p+50808?r=allmovie      benign
# 812197   fcciq.com/e_photo_album.asp?the_event=New%20go...      benign

# %%
merge_data.shape
# Out:
# (1156174, 2)

# %%
merge_data.isnull().sum()
# Out:
# URL      0
# label    0
# dtype: int64

# %%
merge_data.duplicated().sample(10)
# Out:
# 361793    False
# 690170    False
# 122440    False
# 166336    False
# 945648    False
# 874869    False
# 249250    False
# 456723    False
# 105882    False
# 961484    False
# dtype: bool

# %%
merge_data['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %% [markdown]
# ## Label Encoding Mean we give [ 0 - Safe or 1 - Malicious ]

# %%
# Example: Sabko 0 (safe) aur 1 (malicious) mein convert karo
def standardize_label(label):
    if isinstance(label, str):
        label = label.lower()
        if label in ['benign', 'legitimate']:
            return 0
        elif label in ['phishing', 'malware', 'defacement']:
            return 1
    return label  

merge_data['label'] = merge_data['label'].apply(standardize_label)

# %%
merge_data.sample(10)
# Out:
#                                                        URL  label
# 1142867           groups.yahoo.com/group/TerragenPLUSPost/      1
# 777786   wildcatsthunder.blogspot.com/2009/07/uk-basket...      0
# 1011071                        annuity.top-companies.info/      0
# 179311                   https://www.electronicaems.co.uk/      0
# 416481                       http://knightsure.co.uk/nr8e7      1
# 143908     https://www.astralradioplus.com/news.php?idN=79      0
# 67595    https://www.local.yahoo.com/info-17800864-metr...      0
# 706382   celebjihad.com/celeb-jihad/rapper-t-i-caught-w...      0
# 1104280                               giftssteam.p2h.info/      0
# 907803                                   chitiandsandes.gq      1

# %%
merge_data['label'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
merge_data['label'].value_counts()
# Out:
# label
# 0    773841
# 1    382333
# Name: count, dtype: int64

# %%
merge_data['URL'].duplicated().sample(10)
# Out:
# 490657     False
# 571783     False
# 1003521    False
# 787090     False
# 885063     False
# 611086     False
# 278463     False
# 873497     False
# 1090089    False
# 732534     False
# Name: URL, dtype: bool

# %%
merge_data.shape
# Out:
# (1156174, 2)

# %%
merge_data = merge_data.drop_duplicates()

# %%
merge_data['URL'].duplicated().sample(10)
# Out:
# 279147     False
# 1092162    False
# 167040     False
# 616742     False
# 350948     False
# 895959     False
# 1083674    False
# 822839     False
# 1131473    False
# 220111     False
# Name: URL, dtype: bool

# %%
merge_data.shape
# Out:
# (1144960, 2)

# %%
merge_data['label'].value_counts()
# Out:
# label
# 0    773818
# 1    371142
# Name: count, dtype: int64

# %% [markdown]
# ## URL Cleaning

# %%
merge_data['has_https'] = merge_data['URL'].apply(lambda x: 1 if 'https' in x else 0)

merge_data['URL'] = merge_data['URL'].str.lower()
merge_data['URL'] = merge_data['URL'].str.replace('http://','')
merge_data['URL'] = merge_data['URL'].str.replace('https://','')
merge_data['URL'] = merge_data['URL'].str.replace('www.','')
merge_data['URL'] = merge_data['URL'].str.strip()

# %%
merge_data.sample(10)
# Out:
#                                                        URL  label  has_https
# 422190   refreshdharan.com/bg/excel2/index.php?userid={...      1          0
# 279746   reddit.com/r/rhps/comments/kvvf5/its_my_first_...      0          1
# 610993                poker-bets.net/artcles/poker-basic.1      1          0
# 34552    en.wikipedia.org/wiki/isabelle_blais_(actress_...      0          1
# 816901     soccerbase.com/players/player.sd?player_id=1957      0          0
# 881090               spoke.com/info/p12ry4e/brianmacdonald      0          0
# 922904                     youtube.com/artist/david_murray      0          0
# 487980   ipfs.eth.aragon.network/ipfs/bafkreifc4ed2vegr...      1          1
# 1035935  nightvision.tech/assets/formoid/categories/cat...      1          0
# 605678                  justgottascoot.com/flyscooters.htm      0          0

# %% [markdown]
#   ## Feature Extraction

# %%
# import re

# # URL Length
# merge_data['url_length'] = merge_data['URL'].apply(len)

# # Number of dots
# merge_data['dot_count'] = merge_data['URL'].apply(lambda x: x.count('.'))

# # Number of slashes
# merge_data['slash_count'] = merge_data['URL'].apply(lambda x: x.count('/'))

# # HTTPS presence
# # merge_data['has_https'] = merge_data['URL'].apply(lambda x: 1 if 'https' in x else 0)

# # Special characters count
# merge_data['special_char_count'] = merge_data['URL'].apply(lambda x: len(re.findall(r'[^a-zA-Z0-9]', x)))

# # Number of digits
# merge_data['digit_count'] = merge_data['URL'].apply(lambda x: sum(c.isdigit() for c in x))

# # Hyphen count 
# merge_data['hyphen_count'] = merge_data['URL'].apply(lambda x: x.count('-'))

# # Subdomain Count
# merge_data['subdomain_count'] = merge_data['URL'].apply(lambda x: x.count('.') - 1)

# # suspicious words
# suspicious_words = ['login','secure','verify','account','update','bank']
# merge_data['suspicious_word'] = merge_data['URL'].apply(
#     lambda x: int(any(word in x for word in suspicious_words))
# )

# # Check new dataset
# merge_data.sample(10)

# %%
import re
from urllib.parse import urlparse

# Suspicious words list
suspicious_words = ['login','secure','verify','account','update','bank']

# Suspicious domains list
suspicious_domains = [
    'duckdns.org', '000webhostapp.com', 'herokuapp.com',
    'netlify.app', 'onrender.com', 'xyz', 'tk'
]

# URL Length
merge_data['url_length'] = merge_data['URL'].apply(len)

# Number of dots
merge_data['dot_count'] = merge_data['URL'].apply(lambda x: x.count('.'))

# Number of slashes
merge_data['slash_count'] = merge_data['URL'].apply(lambda x: x.count('/'))


# Special characters count
merge_data['special_char_count'] = merge_data['URL'].apply(
    lambda x: len(re.findall(r'[^a-zA-Z0-9]', x))
)

# Number of digits
merge_data['digit_count'] = merge_data['URL'].apply(
    lambda x: sum(c.isdigit() for c in x)
)

# Hyphen count 
merge_data['hyphen_count'] = merge_data['URL'].apply(lambda x: x.count('-'))

# Subdomain Count
merge_data['subdomain_count'] = merge_data['URL'].apply(
    lambda x: x.count('.') - 1 if x.count('.') > 0 else 0
)

# Suspicious word presence (0/1)
merge_data['suspicious_word'] = merge_data['URL'].apply(
    lambda x: int(any(word in x.lower() for word in suspicious_words))
)

# Suspicious word count 
merge_data['suspicious_word_count'] = merge_data['URL'].apply(
    lambda x: sum(x.lower().count(word) for word in suspicious_words)
)
# URL uses IP instead of domain 
merge_data['has_ip'] = merge_data['URL'].apply(
    lambda x: 1 if re.search(r'\d+\.\d+\.\d+\.\d+', x) else 0
)

# Long URL flag
merge_data['is_long_url'] = merge_data['url_length'].apply(
    lambda x: 1 if x > 75 else 0
)

# Digit ratio 
merge_data['digit_ratio'] = merge_data.apply(
    lambda row: row['digit_count'] / row['url_length'] if row['url_length'] > 0 else 0,
    axis=1
)

# Check dataset
merge_data.sample(10)
# Out:
#                                                        URL  label  has_https  \
# 345663                             synaptic.bc.ca/gallery/      0          1
# 164373                     clanegan.org/lineage/index3.htm      0          1
# 884000                                 reunion.com/l3-253/      0          0
# 595259   kenh14.vn/doi-song/can-canh-hang-son-doong-tre...      0          0
# 521033             tvguide.com/celebrities/sheila-e/174462      0          0
# 917682                    en.wikipedia.org/wiki/red_fisher      0          0
# 1145549          jinr.ru/programs/jinrlib/mavi/indexe.html      1          0
# 711038              creative-decorating.co.uk/gallery.html      1          0
# 583956                         atualizacaobancodigital.com      1          0
# 239369   lyricsmania.com/wrong_choice_lyrics_lovely_fea...      0          1
#
#          url_length  dot_count  slash_count  special_char_count  digit_count  \
# 345663           23          2            2                   4            0
# 164373           31          2            2                   4            1
# 884000           19          1            2                   4            4
# 595259          120          2            2                  21           19
# 521033           39          1            3                   5            6
# 917682           32          2            2                   5            0
# 1145549          41          2            4                   6            0
# 711038           38          3            1                   5            0
# 583956           27          1            0                   1            0
# 239369           60          2            1                   8            0
#
#          hyphen_count  subdomain_count  suspicious_word  \
# 345663              0                1                0
# 164373              0                1                0
# 884000              1                0                0
# 595259             17                1                0
# 521033              1                0                0
# 917682              0                1                0
# 1145549             0                1                0
# 711038              1                2                0
# 583956              0                0                0
# 239369              0                1                0
#
#          suspicious_word_count  has_ip  is_long_url  digit_ratio
# 345663                       0       0            0     0.000000
# 164373                       0       0            0     0.032258
# 884000                       0       0            0     0.210526
# 595259                       0       0            1     0.158333
# 521033                       0       0            0     0.153846
# 917682                       0       0            0     0.000000
# 1145549                      0       0            0     0.000000
# 711038                       0       0            0     0.000000
# 583956                       0       0            0     0.000000
# 239369                       0       0            0     0.000000

# %% [markdown]
# ## 6. Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = merge_data[['url_length','dot_count','slash_count','special_char_count','digit_count','hyphen_count','subdomain_count',
                'suspicious_word','suspicious_word_count','has_ip','is_long_url','digit_ratio']]

Y = merge_data['label']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (915968, 12)

# %% [markdown]
# ## 6. Model Training

# %% [markdown]
# #### 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# #### 2. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=500,
    max_depth=20, 
    min_samples_split=5,  
    min_samples_leaf=2,
    random_state=42,
    class_weight="balanced"
)
rf_model.fit(X_train, Y_train)

# %% [markdown]
# #### 3. XGBoost
#       1. Large dataset me strong
#       2. URL feature data par achchha kaam karta hai
#       3. Fraud detection me high recall deta hai

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\saanjh\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\saanjh\appdata\roaming\python\python313\site-packages (from xgboost) (2.2.5)
# Requirement already satisfied: scipy in c:\users\saanjh\anaconda3\lib\site-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

xboost = XGBClassifier(
    n_estimators=300,
    learning_rate=0.01,
    scale_pos_weight=2.08,
    use_label_encoder=False,
    eval_metric='logloss',
    max_depth=6
)

xboost.fit(X_train, Y_train)
# Out:
# c:\Users\saanjh\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [22:31:41] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ## 7. Model Prediction

# %%
# Logistic Regression
log_pred = log_model.predict(X_test)

# Random Forest
rf_pred = rf_model.predict(X_test)

# XGBoost
xb_pred = xboost.predict(X_test)

# %% [markdown]
# ####  Threshold use for Improve Recall accurecy

# %%
# rf_probs = rf_model.predict_proba(X_test)[:,1]   # probability nikaalo

# threshold = 0.3  # change this

# rf_pred = (rf_probs >= threshold).astype(int)
# Random Forest Report
#               precision    recall  f1-score   support

#            0       0.96      0.71      0.82    154523
#            1       0.61      0.93      0.74     74469

#     accuracy                           0.78    228992
#    macro avg       0.78      0.82      0.78    228992
# weighted avg       0.84      0.78      0.79    228992

# %% [markdown]
# ## 8. Model Accuracy Check

# %%
from sklearn.metrics import accuracy_score  # prevous Random Forest = 83.35

print("Logistic Regression Accuracy:", accuracy_score(Y_test, log_pred))
print("Random Forest Accuracy:", accuracy_score(Y_test, rf_pred))
print("XGBoost: ",accuracy_score(Y_test,xb_pred))
# Out:
# Logistic Regression Accuracy: 0.7106405463946339
# Random Forest Accuracy: 0.8115742034656233
# XGBoost:  0.7588693054779206

# %% [markdown]
# #### Cross Validation Score

# %%
# from sklearn.model_selection import cross_val_score
# scores = cross_val_score(rf_model, X, Y, cv=5)
# print(scores.mean())

# %% [markdown]
# ## 9. Detailed Evaluation

# %%
print("Logistic Regression Report")
print(classification_report(Y_test, log_pred))

print("Random Forest Report")
print(classification_report(Y_test, rf_pred))

print("XGboost Report")
print(classification_report(Y_test, xb_pred))
# Out:
# Logistic Regression Report
#               precision    recall  f1-score   support
#
#            0       0.71      0.95      0.82    154523
#            1       0.68      0.21      0.32     74469
#
#     accuracy                           0.71    228992
#    macro avg       0.70      0.58      0.57    228992
# weighted avg       0.70      0.71      0.65    228992
#
# Random Forest Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85    154523
#            1       0.68      0.81      0.74     74469
#
#     accuracy                           0.81    228992
#    macro avg       0.79      0.81      0.79    228992
# weighted avg       0.83      0.81      0.82    228992
#
# XGboost Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81    154523
#            1       0.61      0.73      0.66     74469
#
#     accuracy                           0.76    228992
#    macro avg       0.73      0.75      0.74    228992
# weighted avg       0.78      0.76      0.76    228992

# %% [markdown]
# # 10. Random Forest

# %% [markdown]
# ### How I select Feature for my model Traning
#      “We used feature importance to understand which URL characteristics influence the model’s decision most,
#       such as suspicious keywords, URL length, and HTTPS usage.”

# %%
import matplotlib.pyplot as plt

feature_names = [
    "url_length", "dots", "slashes", "special_chars",
    "digits", "hyphens", "subdomains", "suspicious_flag",
    "suspicious_count",  "has_ip",
    "long_url", "digit_ratio"
]

importances = rf_model.feature_importances_

# Plot
plt.barh(feature_names, importances)
plt.xlabel("Importance")
plt.title("Feature Importance")
plt.show()

# %% [markdown]
# ### Model Testing using Real Data

# %%
url_features = [[0,50,2,3,3,3,3,1,0,5,8,0]]

prediction = rf_model.predict(url_features)

if prediction[0] == 1:
    print("⚠ Fraud URL")
else:
    print("✅ Safe URL")
# Out:
# ⚠ Fraud URL
# c:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Real URL testing of Random Forest

# %% [markdown]
# #### URL Se Features Extract Karo

# %%
# import re

# url = "https://developers.google.com/profile/u/110426891037394042089/dashboard"

# has_https = 1 if "https" in url else 0
# url_length = len(url)
# dot_count = url.count(".")
# slash_count = url.count("/")
# special_char_count = len(re.findall(r"[!@#$%^&*(),?\":{}|<>]", url))
# digit_count = sum(c.isdigit() for c in url)
# hyphen_count = url.count("-")
# subdomain_count = dot_count - 1


# features = [[has_https,url_length,dot_count,slash_count,
#              special_char_count,digit_count,
#              hyphen_count,subdomain_count]]

url = "https://developers.google.com/profile/u/110426891037394042089/dashboard"

suspicious_words = ['login','verify','bank','update','secure','account','ad']

def extract_features(url):
    import re
    
    len(url),                                                    # url_length
    url.count("."),                                              # dot_count
    url.count("/"),                                              # slash_count
    len(re.findall(r'[^a-zA-Z0-9]', url)),                      # special_char_count
    sum(c.isdigit() for c in url),                               # digit_count
    url.count("-"),                                              # hyphen_count
    max(url.count(".") - 1, 0),                                  # subdomain_count
    1 if sum(url.lower().count(w) for w in suspicious_words) > 0 else 0,  # suspicious_word flag
    sum(url.lower().count(w) for w in suspicious_words),        # suspicious_word_count
    # 1 if any(domain.endswith(tld) for tld in [".com", ".org", ".net", ".edu", ".gov"]) else 0,  # domain_flag
    1 if re.match(r'^(\d{1,3}\.){3}\d{1,3}$', domain) else 0,  # has_ip
    1 if len(url) > 75 else 0,                                   # is_long_url
    sum(c.isdigit() for c in url)/len(url) if len(url) > 0 else 0  # digit_ratio

    features = [
        'url_length','dot_count','slash_count','special_char_count','digit_count','hyphen_count','subdomain_count',
                'suspicious_word','suspicious_word_count','has_ip','is_long_url','digit_ratio' 
    ]
    return features

# %% [markdown]
# ####  Prediction using Model

# %%
prediction = rf_model.predict(features)

if prediction[0] == 1:
    print("⚠ Fraud URL")
else:
    print("✅ Safe URL")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 prediction = rf_model.predict(features)
#       3 if prediction[0] == 1:
#       4     print("⚠ Fraud URL")
#
# NameError: name 'features' is not defined

# %%
results = pd.DataFrame({
    "Actual": Y_test,
    "Predicted": rf_pred
})

print(results.sample(10))
# Out:
#          Actual  Predicted
# 1060205       0          1
# 127756        0          0
# 175085        0          0
# 802481        0          0
# 654769        1          1
# 1081863       0          0
# 380396        1          1
# 751333        1          1
# 769465        0          1
# 1155875       1          0

# %% [markdown]
# ### Confusion Matrix of Random forest

# %%
# 4️ Confusion Matrix
from sklearn.metrics import confusion_matrix

print("Confusion Matrix:")
print(confusion_matrix(Y_test, rf_pred))
# Out:
# Confusion Matrix:
# [[125724  28799]
#  [ 14349  60120]]

# %% [markdown]
# ### Save Test prediction Data of Random Forest

# %%
# 7️ CSV me save karna
results.to_csv("test_predictions.csv", index=False)

print("\nPrediction results saved as test_predictions.csv")
# Out:
# Prediction results saved as test_predictions.csv

# %% [markdown]
# ### Model Save Random Forest

# %%
import pickle

pickle.dump(rf_model, open("Model/qr_fraud_model.pkl", "wb"))

# %% [markdown]
# # 11. XGboost

# %%
results = pd.DataFrame({
    "Actual": Y_test,
    "Predicted": xb_pred
})

print(results.sample(10))
# Out:
#          Actual  Predicted
# 152509        0          0
# 167844        0          0
# 89312         0          0
# 202570        0          0
# 682540        1          0
# 13511         0          1
# 673280        0          0
# 867790        0          0
# 332464        0          0
# 1133301       1          0

# %%
# 4️ Confusion Matrix
from sklearn.metrics import confusion_matrix

print("Confusion Matrix:")
print(confusion_matrix(Y_test, xb_pred))
# Out:
# Confusion Matrix:
# [[119248  35275]
#  [ 19942  54527]]

# %% [markdown]
# # Load Random forest Model

# %%
rf = pickle.load(open("Model/qr_fraud_model.pkl","rb"))

# %% [markdown]
# ## Reasion Behind Safe or Fraud

# %%
def explain_url(url, prediction):
    reasons = []

    if prediction == 1:  # Fraud
        if len(url) > 50:
            reasons.append("Long URL")
        if sum(c.isdigit() for c in url) > 5:
            reasons.append("Too many digits")
        if url.count('.') > 3:
            reasons.append("Too many subdomains")
        if "https" not in url:
            reasons.append("No HTTPS")
        if '-' in url:
            reasons.append("Contains hyphen")
        if any(word in url.lower() for word in suspicious_words):
            reasons.append("Contains suspicious words")

    else:  # Safe
        if "https" in url:
            reasons.append("Uses HTTPS")
        if len(url) < 50:
            reasons.append("Short URL")
        if sum(c.isdigit() for c in url) < 5:
            reasons.append("Less digits")
        if url.count('.') <= 3:
            reasons.append("Normal structure")
        if '-' not in url:
            reasons.append("No suspicious symbols")

    return ", ".join(reasons)

# %% [markdown]
# #### Model testing using real URL

# %%
# import pickle
# # Suspicious words list-
# suspicious_words = ['login','secure','verify','account','update','bank']

# #  Feature extraction function
# def extract_features(url):
#     has_https = 1 if "https" in url else 0
#     url_length = len(url)
#     dot_count = url.count(".")
#     slash_count = url.count("/")
#     special_char_count = len(re.findall(r'[^a-zA-Z0-9]', url))
#     digit_count = sum(c.isdigit() for c in url)
#     hyphen_count = url.count("-")
#     subdomain_count = dot_count - 1 if dot_count > 0 else 0
#     suspicious_word_count = sum(url.lower().count(word) for word in suspicious_words)

#     features = [
#         has_https,
#         url_length,
#         dot_count,
#         slash_count,
#         special_char_count,
#         digit_count,
#         hyphen_count,
#         subdomain_count,
#         suspicious_word_count
#     ]
    
#     return features

# # Single URL Prediction
# def predict_url(url):
#     features = extract_features(url)
#     prediction = rf.predict([features])[0]
#     explanation = explain_url(url, prediction)
#     label = "⚠ Fraud URL" if prediction == 1 else "✅ Safe URL"
#     return label, explanation

# #  Multiple URLs Prediction (DataFrame)
# def predict_urls(df, url_column='URL'):
#     df = df.copy()
#     results = []
#     explanations = []
#     for url in df[url_column]:
#         features = extract_features(url)
#         pred = rf.predict([features])[0]

#         label = "⚠ Fraud URL" if pred == 1 else "✅ Safe URL"
#         explanation = explain_url(url, pred)

#         results.append(label)
#         explanations.append(explanation)

#     df['Prediction'] = results
#     df['Explanation'] = explanations
#     return df

# # Example Usage
# test_df = pd.DataFrame({
#     'URL': [
#         "https://google.com",
#         "http://bank-login-secure.xyz",
#         "https://example.com",
#         "https://spark.iitr.ac.in/",
#         "https://www.google.com/about/careers/applications/apply/d028d74b-3f01-42af-97f6-90f78e39c4b5/review",
#         "https://hack2skill.com/?utm_source=hack2skill&utm_medium=homepage",
#         "https://fake-news-project-2i3o.onrender.com/",
#         "https://chatgpt.com/c/69b7b96e-0a5c-8322-ba24-5201893caf62",
#         "http://localhost:8888/tree/Advanced%20QR%20Fraud%20Detection",
#         "https://docs-cybersec.thalesgroup.com/bundle/on-premises-knowledgebase-reference-guide/page/abnormally_long_url.htm",
#         "https://hack2skill.com/?utm_source=hack2skill&utm_medium=homepage#whyH2s",
#         "corporationwiki.com/Ohio/Columbus/frank-s-benson-P3333917.aspx",
#         "http://www.ikenmijnkunst.nl/index.php/exposities/exposities-2006",
#         "signin.eby.de.zukruygxctzmmqi.civpro.co.za"
#     ]
# })

# predicted_df = predict_urls(test_df)
# print(predicted_df)

# %%
import re
from urllib.parse import urlparse

# Suspicious words list
suspicious_words = ['login','secure','verify','account','update','bank']

# Suspicious domains list
suspicious_domains = ['duckdns.org','onrender.com','000webhostapp.com','aaff.xyz','sjdj.tk']

# Feature extraction function
def extract_features(url):
    parsed = urlparse(url)
    domain = parsed.netloc.lower()

    # Basic features
    url_length = len(url)
    dot_count = url.count(".")
    slash_count = url.count("/")
    special_char_count = len(re.findall(r'[^a-zA-Z0-9]', url))
    digit_count = sum(c.isdigit() for c in url)
    hyphen_count = url.count("-")
    subdomain_count = dot_count - 1 if dot_count > 0 else 0

    # Suspicious words
    suspicious_word_count = sum(url.lower().count(word) for word in suspicious_words)

    # 🔥 Advanced features
    has_ip = 1 if re.search(r'\d+\.\d+\.\d+\.\d+', url) else 0
    is_long_url = 1 if url_length > 75 else 0

    # 🔥 EXTRA (to make 14 features)
    digit_ratio = digit_count / url_length if url_length > 0 else 0
    special_char_ratio = special_char_count / url_length if url_length > 0 else 0

    features = [
        url_length,             # 1
        dot_count,              # 2
        slash_count,            # 3
        special_char_count,     # 4
        digit_count,            # 5
        hyphen_count,           # 6
        subdomain_count,        # 7
        suspicious_word_count,  # 8
        has_ip,                 # 9
        is_long_url,            # 10
        digit_ratio,            # 11
        special_char_ratio      # 12
    ]

    return features
 


# Single URL Prediction
def predict_url(url):
    features = extract_features(url)
    prediction = rf.predict([features])[0]
    explanation = explain_url(url, prediction)

    label = "⚠ Fraud URL" if prediction == 1 else "✅ Safe URL"
    return label, explanation


# Multiple URLs Prediction
def predict_urls(df, url_column='URL'):
    df = df.copy()
    results = []
    explanations = []

    for url in df[url_column]:
        features = extract_features(url)
        pred = rf.predict([features])[0]

        label = "⚠ Fraud URL" if pred == 1 else "✅ Safe URL"
        explanation = explain_url(url, pred)

        results.append(label)
        explanations.append(explanation)

    df['Prediction'] = results
    df['Explanation'] = explanations
    return df


# Example Usage
test_df = pd.DataFrame({
    'URL': [
        "https://google.com",
        "http://bank-login-secure.xyz",
        "https://example.com",
        "https://spark.iitr.ac.in/",
        "https://www.google.com/about/careers/applications/apply/d028d74b-3f01-42af-97f6-90f78e39c4b5/review",
        "https://hack2skill.com/?utm_source=hack2skill&utm_medium=homepage",
        "https://fake-news-project-2i3o.onrender.com/",
        "https://chatgpt.com/c/69b7b96e-0a5c-8322-ba24-5201893caf62",
        "http://localhost:8888/tree/Advanced%20QR%20Fraud%20Detection",
        "https://docs-cybersec.thalesgroup.com/bundle/on-premises-knowledgebase-reference-guide/page/abnormally_long_url.htm",
        "signin.eby.de.zukruygxctzmmqi.civpro.co.za",
        "http://mobildeniz2025firsatlari.duckdns.org/"
    ]
})

predicted_df = predict_urls(test_df)
print(predicted_df)
# Out:
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
#                                                   URL   Prediction  \
# 0                                  https://google.com  ⚠ Fraud URL
# 1                        http://bank-login-secure.xyz   ✅ Safe URL
# 2                                 https://example.com  ⚠ Fraud URL
# 3                           https://spark.iitr.ac.in/  ⚠ Fraud URL
# 4   https://www.google.com/about/careers/applicati...   ✅ Safe URL
# 5   https://hack2skill.com/?utm_source=hack2skill&...   ✅ Safe URL
# 6        https://fake-news-project-2i3o.onrender.com/   ✅ Safe URL
# 7   https://chatgpt.com/c/69b7b96e-0a5c-8322-ba24-...   ✅ Safe URL
# 8   http://localhost:8888/tree/Advanced%20QR%20Fra...   ✅ Safe URL
# 9   https://docs-cybersec.thalesgroup.com/bundle/o...  ⚠ Fraud URL
# 10         signin.eby.de.zukruygxctzmmqi.civpro.co.za  ⚠ Fraud URL
# 11       http://mobildeniz2025firsatlari.duckdns.org/   ✅ Safe URL
#
#                                           Explanation
# 0
# 1            Short URL, Less digits, Normal structure
# 2
# 3
# 4                        Uses HTTPS, Normal structure
# 5   Uses HTTPS, Less digits, Normal structure, No ...
# 6   Uses HTTPS, Short URL, Less digits, Normal str...
# 7                        Uses HTTPS, Normal structure
# 8             Normal structure, No suspicious symbols
# 9                           Long URL, Contains hyphen
# 10                      Too many subdomains, No HTTPS
# 11  Short URL, Less digits, Normal structure, No s...
# C:\Users\saanjh\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
